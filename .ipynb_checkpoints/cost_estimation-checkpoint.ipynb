# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %% [markdown]
# **Read the Data**

# %%
df = pd.read_excel("cost_estimate_raw_data.xlsx")
df.columns = [x.replace(r' ', '') for x in list(df)]
df.sample(15)
# Out:
#     FactoryOverhead  LabourHours  MachineHours  RawMaterials
# 10           157608         1992          1171           445
# 19           145379         1747          1052           517
# 25           166110         1658          1015           660
# 13           171982         2256           950           688
# 4            166605         1930           952           678
# 11           171700         2476          1228           581
# 3            178059         1584          1480           479
# 26           150041         2042           971           478
# 20           152614         1618           860           640
# 9            144605         1723           869           489
# 21           159450         2122          1188           548
# 27           170419         1757          1111           652
# 0            137896         2092           959           414
# 6            157585         2319           931           585
# 12           140686         2087           928           446

# %% [markdown]
# **Plot FactoryOverhead against  LabourHours**

# %%
df.plot.scatter(y = "FactoryOverhead", x="LabourHours")
# Out:
# <AxesSubplot:xlabel='LabourHours', ylabel='FactoryOverhead'>

# %% [markdown]
# **Plot the cost with estimated regression line**

# %%
def graph_cost(data, i):
    df.plot.scatter(y = "FactoryOverhead", x= i)
    sns.regplot(data=data, x=i, y="FactoryOverhead", scatter=False, color=".01")
    plt.show()

graph_cost(df, "LabourHours")

# %% [markdown]
# **Now for all**

# %%
for i in list(df)[1:]:
    graph_cost(df, i)
    print(i)
# Out:
# LabourHours
# MachineHours
# RawMaterials

# %% [markdown]
# **Now run regressions to find the relevant cost parameters**

# %%
def regressy(data, indepvar):
    x = data[indepvar]
    y = data['FactoryOverhead']
    x = sm.add_constant(x)
    # Note the difference in argument order
    res = sm.OLS(y, x).fit()
    #predictions = model.predict(X) # make the predictions by the model
    print(res.summary())
    print(f'\nFixed cost: ${res.params[0]:4,.0f}')
    print(f'Variable cost: ${res.params[1]:4,.2f}, per unit of {indepvar}.\n')
    return(res)

res = regressy(df, 'MachineHours')
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        FactoryOverhead   R-squared:                       0.457
# Model:                            OLS   Adj. R-squared:                  0.438
# Method:                 Least Squares   F-statistic:                     25.20
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):           2.20e-05
# Time:                        10:09:50   Log-Likelihood:                -335.16
# No. Observations:                  32   AIC:                             674.3
# Df Residuals:                      30   BIC:                             677.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1.129e+05   9340.965     12.088      0.000    9.38e+04    1.32e+05
# MachineHours    42.2498      8.416      5.020      0.000      25.062      59.438
# ==============================================================================
# Omnibus:                        1.155   Durbin-Watson:                   2.184
# Prob(Omnibus):                  0.561   Jarque-Bera (JB):                0.965
# Skew:                           0.181   Prob(JB):                        0.617
# Kurtosis:                       2.230   Cond. No.                     6.63e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.63e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Fixed cost: $112,915
# Variable cost: $42.25, per unit of MachineHours.

# %%
for i in list(df)[1:]:
    regressy(df, i)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        FactoryOverhead   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.042
# Method:                 Least Squares   F-statistic:                     2.345
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):              0.136
# Time:                        10:09:54   Log-Likelihood:                -343.71
# No. Observations:                  32   AIC:                             691.4
# Df Residuals:                      30   BIC:                             694.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1.379e+05    1.4e+04      9.826      0.000    1.09e+05    1.67e+05
# LabourHours    10.9862      7.174      1.531      0.136      -3.665      25.638
# ==============================================================================
# Omnibus:                        0.635   Durbin-Watson:                   2.142
# Prob(Omnibus):                  0.728   Jarque-Bera (JB):                0.707
# Skew:                          -0.162   Prob(JB):                        0.702
# Kurtosis:                       2.348   Cond. No.                     1.34e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.34e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Fixed cost: $137,887
# Variable cost: $10.99, per unit of LabourHours.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        FactoryOverhead   R-squared:                       0.457
# Model:                            OLS   Adj. R-squared:                  0.438
# Method:                 Least Squares   F-statistic:                     25.20
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):           2.20e-05
# Time:                        10:09:54   Log-Likelihood:                -335.16
# No. Observations:                  32   AIC:                             674.3
# Df Residuals:                      30   BIC:                             677.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1.129e+05   9340.965     12.088      0.000    9.38e+04    1.32e+05
# MachineHours    42.2498      8.416      5.020      0.000      25.062      59.438
# ==============================================================================
# Omnibus:                        1.155   Durbin-Watson:                   2.184
# Prob(Omnibus):                  0.561   Jarque-Bera (JB):                0.965
# Skew:                           0.181   Prob(JB):                        0.617
# Kurtosis:                       2.230   Cond. No.                     6.63e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.63e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Fixed cost: $112,915
# Variable cost: $42.25, per unit of MachineHours.
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        FactoryOverhead   R-squared:                       0.338
# Model:                            OLS   Adj. R-squared:                  0.316
# Method:                 Least Squares   F-statistic:                     15.34
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):           0.000481
# Time:                        10:09:54   Log-Likelihood:                -338.31
# No. Observations:                  32   AIC:                             680.6
# Df Residuals:                      30   BIC:                             683.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         1.199e+05   1.02e+04     11.772      0.000    9.91e+04    1.41e+05
# RawMaterials    71.6313     18.291      3.916      0.000      34.276     108.987
# ==============================================================================
# Omnibus:                        1.604   Durbin-Watson:                   1.632
# Prob(Omnibus):                  0.449   Jarque-Bera (JB):                1.493
# Skew:                           0.472   Prob(JB):                        0.474
# Kurtosis:                       2.523   Cond. No.                     3.29e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.29e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Fixed cost: $119,853
# Variable cost: $71.63, per unit of RawMaterials.

# %% [markdown]
# **Lastly: multivariate regression**

# %%
def multiple_regress(data):
    x = data[['LabourHours', 'MachineHours', 'RawMaterials']]
    y = data['FactoryOverhead']
    x = sm.add_constant(x)
    # Note the difference in argument order
    res = sm.OLS(y, x).fit()
    #predictions = model.predict(X) # make the predictions by the model
    print(res.summary())
    print(f'\nFixed cost: ${res.params[0]:4,.0f}')
    return(res)

res = multiple_regress(df)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        FactoryOverhead   R-squared:                       0.835
# Model:                            OLS   Adj. R-squared:                  0.817
# Method:                 Least Squares   F-statistic:                     47.17
# Date:                Wed, 16 Nov 2022   Prob (F-statistic):           4.48e-11
# Time:                        10:09:58   Log-Likelihood:                -316.10
# No. Observations:                  32   AIC:                             640.2
# Df Residuals:                      28   BIC:                             646.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const          7.15e+04   8484.446      8.427      0.000    5.41e+04    8.89e+04
# LabourHours     -1.8113      3.330     -0.544      0.591      -8.633       5.010
# MachineHours    44.7820      5.001      8.954      0.000      34.537      55.027
# RawMaterials    76.8413      9.717      7.908      0.000      56.937      96.746
# ==============================================================================
# Omnibus:                        0.667   Durbin-Watson:                   1.440
# Prob(Omnibus):                  0.716   Jarque-Bera (JB):                0.734
# Skew:                          -0.181   Prob(JB):                        0.693
# Kurtosis:                       2.352   Cond. No.                     2.20e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.2e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# Fixed cost: $71,497
